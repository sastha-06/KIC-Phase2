# %% [markdown]
# <a href="https://colab.research.google.com/github/sastha-06/KIC-Phase2/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import files
#uploaded = files.upload()
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("train_and_test2.csv")
print(df.columns)

sns.histplot(df['Age'],bins=20)
plt.title("Age Distribution using histogram")
plt.show()

sns.kdeplot(df['Age'])
plt.title("Age Distribution using kdeplot")
plt.show()

sns.boxplot(df['Fare'])
plt.title("outlier detection using boxplot")
plt.show()
# Out:
# Index(['Passengerid', 'Age', 'Fare', 'Sex', 'sibsp', 'zero', 'zero.1',
#        'zero.2', 'zero.3', 'zero.4', 'zero.5', 'zero.6', 'Parch', 'zero.7',
#        'zero.8', 'zero.9', 'zero.10', 'zero.11', 'zero.12', 'zero.13',
#        'zero.14', 'Pclass', 'zero.15', 'zero.16', 'Embarked', 'zero.17',
#        'zero.18', '2urvived'],
#       dtype='object')
