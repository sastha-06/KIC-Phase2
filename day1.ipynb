# %%
#from google.colab import files
#uploaded=files.upload()
import numpy as np
import pandas as pd
df=pd.read_csv("titanic_small.csv")
print(df.head(10))
print("mean of age:",np.mean(df['Age']))
print("median  of age:",np.median(df['Age']))
print("std of age:",np.std(df['Age']))
print("mean of Fare:",np.mean(df['Fare']))
print("median  of Fare:",np.median(df['Fare']))
print("std of Fare:",np.std(df['Fare']))
# Out:
#    PassengerID  Age     Sex  Class   Fare  Survived
# 0            1   22    Male      3   7.25         0
# 1            2   38  Female      1  71.28         1
# 2            3   26  Female      3   7.92         1
# 3            4   35  Female      1  53.10         1
# 4            5   35    Male      3   8.05         0
# 5            6   27    Male      2  13.00         0
# 6            7   54    Male      1  51.86         0
# 7            8    2  Female      3  21.07         1
# 8            9   27  Female      2  11.13         1
# 9           10   14    Male      3  30.07         0
# mean of age: 28.0
# median  of age: 27.0
# std of age: 13.371611720357423
# mean of Fare: 27.473000000000003
# median  of Fare: 17.035
# std of Fare: 22.05304697768542
